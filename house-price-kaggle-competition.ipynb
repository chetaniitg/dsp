# %%
## Importing the Libraries

import pandas as pd ## pandas is used to manupulate the dataframe
import numpy as np ## numpy is used to do scientific calculations
import matplotlib.pyplot as plt ## matplotlib used for visualization
import seaborn as sns ## seaborn used for visualization 
import missingno as msno ## used to visualize missing values
import warnings ## used to remove warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.model_selection import train_test_split,cross_validate, GridSearchCV
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression,Lasso,Ridge,BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

import math
from IPython.display import Image
import warnings
warnings.filterwarnings("ignore")
sns.set(rc={"figure.figsize": (20, 15)})
sns.set_style("whitegrid")

# %%
## Importing the data

df=pd.read_csv('train.csv')

# %%
## Getting the data

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
df.head(10).style.background_gradient(cmap = "viridis")
# Out:
# <style type="text/css">
# #T_0d6a7_row0_col0, #T_0d6a7_row0_col18, #T_0d6a7_row0_col36, #T_0d6a7_row0_col45, #T_0d6a7_row0_col48, #T_0d6a7_row0_col52, #T_0d6a7_row0_col56, #T_0d6a7_row0_col66, #T_0d6a7_row0_col68, #T_0d6a7_row0_col69, #T_0d6a7_row0_col70, #T_0d6a7_row0_col71, #T_0d6a7_row0_col75, #T_0d6a7_row1_col1, #T_0d6a7_row1_col26, #T_0d6a7_row1_col36, #T_0d6a7_row1_col44, #T_0d6a7_row1_col45, #T_0d6a7_row1_col47, #T_0d6a7_row1_col50, #T_0d6a7_row1_col52, #T_0d6a7_row1_col67, #T_0d6a7_row1_col68, #T_0d6a7_row1_col69, #T_0d6a7_row1_col70, #T_0d6a7_row1_col71, #T_0d6a7_row1_col75, #T_0d6a7_row2_col18, #T_0d6a7_row2_col36, #T_0d6a7_row2_col45, #T_0d6a7_row2_col48, #T_0d6a7_row2_col52, #T_0d6a7_row2_col66, #T_0d6a7_row2_col68, #T_0d6a7_row2_col69, #T_0d6a7_row2_col70, #T_0d6a7_row2_col71, #T_0d6a7_row2_col75, #T_0d6a7_row3_col18, #T_0d6a7_row3_col19, #T_0d6a7_row3_col26, #T_0d6a7_row3_col36, #T_0d6a7_row3_col38, #T_0d6a7_row3_col45, #T_0d6a7_row3_col48, #T_0d6a7_row3_col49, #T_0d6a7_row3_col50, #T_0d6a7_row3_col52, #T_0d6a7_row3_col66, #T_0d6a7_row3_col69, #T_0d6a7_row3_col70, #T_0d6a7_row3_col71, #T_0d6a7_row3_col75, #T_0d6a7_row3_col77, #T_0d6a7_row4_col18, #T_0d6a7_row4_col36, #T_0d6a7_row4_col45, #T_0d6a7_row4_col48, #T_0d6a7_row4_col52, #T_0d6a7_row4_col68, #T_0d6a7_row4_col69, #T_0d6a7_row4_col70, #T_0d6a7_row4_col71, #T_0d6a7_row4_col75, #T_0d6a7_row5_col17, #T_0d6a7_row5_col18, #T_0d6a7_row5_col26, #T_0d6a7_row5_col36, #T_0d6a7_row5_col37, #T_0d6a7_row5_col43, #T_0d6a7_row5_col45, #T_0d6a7_row5_col48, #T_0d6a7_row5_col49, #T_0d6a7_row5_col51, #T_0d6a7_row5_col52, #T_0d6a7_row5_col54, #T_0d6a7_row5_col56, #T_0d6a7_row5_col68, #T_0d6a7_row5_col70, #T_0d6a7_row5_col71, #T_0d6a7_row6_col1, #T_0d6a7_row6_col18, #T_0d6a7_row6_col36, #T_0d6a7_row6_col44, #T_0d6a7_row6_col45, #T_0d6a7_row6_col48, #T_0d6a7_row6_col50, #T_0d6a7_row6_col52, #T_0d6a7_row6_col68, #T_0d6a7_row6_col69, #T_0d6a7_row6_col70, #T_0d6a7_row6_col71, #T_0d6a7_row6_col75, #T_0d6a7_row7_col45, #T_0d6a7_row7_col48, #T_0d6a7_row7_col52, #T_0d6a7_row7_col69, #T_0d6a7_row7_col70, #T_0d6a7_row7_col71, #T_0d6a7_row8_col4, #T_0d6a7_row8_col18, #T_0d6a7_row8_col20, #T_0d6a7_row8_col26, #T_0d6a7_row8_col34, #T_0d6a7_row8_col36, #T_0d6a7_row8_col45, #T_0d6a7_row8_col47, #T_0d6a7_row8_col48, #T_0d6a7_row8_col50, #T_0d6a7_row8_col59, #T_0d6a7_row8_col67, #T_0d6a7_row8_col69, #T_0d6a7_row8_col70, #T_0d6a7_row8_col71, #T_0d6a7_row8_col75, #T_0d6a7_row9_col3, #T_0d6a7_row9_col17, #T_0d6a7_row9_col20, #T_0d6a7_row9_col26, #T_0d6a7_row9_col36, #T_0d6a7_row9_col44, #T_0d6a7_row9_col45, #T_0d6a7_row9_col46, #T_0d6a7_row9_col48, #T_0d6a7_row9_col49, #T_0d6a7_row9_col50, #T_0d6a7_row9_col54, #T_0d6a7_row9_col61, #T_0d6a7_row9_col62, #T_0d6a7_row9_col66, #T_0d6a7_row9_col68, #T_0d6a7_row9_col69, #T_0d6a7_row9_col70, #T_0d6a7_row9_col71, #T_0d6a7_row9_col75, #T_0d6a7_row9_col76, #T_0d6a7_row9_col80 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col1, #T_0d6a7_row2_col1, #T_0d6a7_row4_col1, #T_0d6a7_row7_col1 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col3, #T_0d6a7_row1_col4 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col4, #T_0d6a7_row3_col3 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col17, #T_0d6a7_row0_col51, #T_0d6a7_row0_col77, #T_0d6a7_row1_col51, #T_0d6a7_row2_col17, #T_0d6a7_row2_col51, #T_0d6a7_row2_col77, #T_0d6a7_row3_col17, #T_0d6a7_row3_col51, #T_0d6a7_row4_col77, #T_0d6a7_row6_col0, #T_0d6a7_row6_col51, #T_0d6a7_row7_col17, #T_0d6a7_row7_col51, #T_0d6a7_row8_col17, #T_0d6a7_row8_col77, #T_0d6a7_row9_col77 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col19 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_0d6a7_row0_col20 {
#   background-color: #e7e419;
#   color: #000000;
# }
# #T_0d6a7_row0_col26 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col34, #T_0d6a7_row1_col43 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col37 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col38 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col43 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col44 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_0d6a7_row0_col46 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col47, #T_0d6a7_row0_col49, #T_0d6a7_row0_col50, #T_0d6a7_row1_col18, #T_0d6a7_row1_col48, #T_0d6a7_row1_col49, #T_0d6a7_row1_col66, #T_0d6a7_row2_col47, #T_0d6a7_row2_col49, #T_0d6a7_row2_col50, #T_0d6a7_row3_col47, #T_0d6a7_row3_col61, #T_0d6a7_row3_col68, #T_0d6a7_row4_col4, #T_0d6a7_row4_col17, #T_0d6a7_row4_col26, #T_0d6a7_row4_col44, #T_0d6a7_row4_col46, #T_0d6a7_row4_col47, #T_0d6a7_row4_col49, #T_0d6a7_row4_col50, #T_0d6a7_row4_col51, #T_0d6a7_row4_col54, #T_0d6a7_row4_col61, #T_0d6a7_row4_col62, #T_0d6a7_row4_col76, #T_0d6a7_row5_col3, #T_0d6a7_row5_col47, #T_0d6a7_row5_col50, #T_0d6a7_row5_col69, #T_0d6a7_row5_col75, #T_0d6a7_row5_col77, #T_0d6a7_row6_col17, #T_0d6a7_row6_col19, #T_0d6a7_row6_col20, #T_0d6a7_row6_col34, #T_0d6a7_row6_col38, #T_0d6a7_row6_col43, #T_0d6a7_row6_col47, #T_0d6a7_row6_col49, #T_0d6a7_row6_col59, #T_0d6a7_row6_col80, #T_0d6a7_row7_col36, #T_0d6a7_row7_col47, #T_0d6a7_row7_col49, #T_0d6a7_row7_col50, #T_0d6a7_row7_col56, #T_0d6a7_row7_col67, #T_0d6a7_row7_col77, #T_0d6a7_row8_col37, #T_0d6a7_row8_col49, #T_0d6a7_row8_col52, #T_0d6a7_row8_col56, #T_0d6a7_row9_col0, #T_0d6a7_row9_col1, #T_0d6a7_row9_col47, #T_0d6a7_row9_col52, #T_0d6a7_row9_col56 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_0d6a7_row0_col54, #T_0d6a7_row8_col54, #T_0d6a7_row8_col68 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_0d6a7_row0_col59 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_0d6a7_row0_col61, #T_0d6a7_row1_col56, #T_0d6a7_row1_col61, #T_0d6a7_row2_col56, #T_0d6a7_row2_col61, #T_0d6a7_row3_col54, #T_0d6a7_row3_col56, #T_0d6a7_row4_col56, #T_0d6a7_row5_col61, #T_0d6a7_row6_col54, #T_0d6a7_row6_col56, #T_0d6a7_row6_col61, #T_0d6a7_row7_col54, #T_0d6a7_row7_col61, #T_0d6a7_row7_col75, #T_0d6a7_row8_col61 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col62, #T_0d6a7_row1_col38 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col67 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col76, #T_0d6a7_row3_col76 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_0d6a7_row0_col80, #T_0d6a7_row4_col34, #T_0d6a7_row4_col37 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col0, #T_0d6a7_row9_col59 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col3, #T_0d6a7_row6_col66 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_0d6a7_row1_col17, #T_0d6a7_row1_col77, #T_0d6a7_row3_col0, #T_0d6a7_row6_col77, #T_0d6a7_row7_col18, #T_0d6a7_row8_col51, #T_0d6a7_row9_col18, #T_0d6a7_row9_col51 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col19, #T_0d6a7_row7_col26 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col20 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col34, #T_0d6a7_row6_col3, #T_0d6a7_row8_col44 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_0d6a7_row1_col37 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col46 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col54, #T_0d6a7_row2_col54, #T_0d6a7_row8_col43, #T_0d6a7_row9_col38 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col59 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col62 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col76, #T_0d6a7_row3_col20 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_0d6a7_row1_col80 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_0d6a7_row2_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_0d6a7_row2_col3 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_0d6a7_row2_col4, #T_0d6a7_row2_col46 {
#   background-color: #29af7f;
#   color: #

# %% [markdown]
# ###### There are 1460 rows and 81 columns in this dataset

# %%
## Basic Checks

df.head()  ## getting first five rows
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.tail() ## getting last five rows
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %%
df.describe().transpose().style.background_gradient(cmap = "magma")
# Out:
# <style type="text/css">
# #T_e0daa_row0_col0, #T_e0daa_row1_col0, #T_e0daa_row3_col0, #T_e0daa_row4_col0, #T_e0daa_row5_col0, #T_e0daa_row6_col0, #T_e0daa_row7_col0, #T_e0daa_row9_col0, #T_e0daa_row10_col0, #T_e0daa_row11_col0, #T_e0daa_row12_col0, #T_e0daa_row13_col0, #T_e0daa_row14_col0, #T_e0daa_row15_col0, #T_e0daa_row16_col0, #T_e0daa_row17_col0, #T_e0daa_row18_col0, #T_e0daa_row19_col0, #T_e0daa_row20_col0, #T_e0daa_row21_col0, #T_e0daa_row22_col0, #T_e0daa_row23_col0, #T_e0daa_row24_col0, #T_e0daa_row26_col0, #T_e0daa_row27_col0, #T_e0daa_row28_col0, #T_e0daa_row29_col0, #T_e0daa_row30_col0, #T_e0daa_row31_col0, #T_e0daa_row32_col0, #T_e0daa_row33_col0, #T_e0daa_row34_col0, #T_e0daa_row35_col0, #T_e0daa_row36_col0, #T_e0daa_row37_col0, #T_e0daa_row37_col1, #T_e0daa_row37_col2, #T_e0daa_row37_col3, #T_e0daa_row37_col4, #T_e0daa_row37_col5, #T_e0daa_row37_col6, #T_e0daa_row37_col7 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_e0daa_row0_col1, #T_e0daa_row0_col2, #T_e0daa_row0_col5, #T_e0daa_row0_col6, #T_e0daa_row9_col2, #T_e0daa_row9_col7, #T_e0daa_row11_col2, #T_e0daa_row12_col1, #T_e0daa_row12_col2, #T_e0daa_row12_col4, #T_e0daa_row12_col5, #T_e0daa_row12_col6, #T_e0daa_row13_col1, #T_e0daa_row13_col2, #T_e0daa_row13_col4, #T_e0daa_row13_col5, #T_e0daa_row13_col6, #T_e0daa_row13_col7, #T_e0daa_row14_col2, #T_e0daa_row16_col2, #T_e0daa_row16_col7, #T_e0daa_row34_col2 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_e0daa_row0_col3, #T_e0daa_row0_col4, #T_e0daa_row0_col7, #T_e0daa_row1_col1, #T_e0daa_row1_col2, #T_e0daa_row1_col3, #T_e0daa_row1_col4, #T_e0daa_row1_col5, #T_e0daa_row1_col6, #T_e0daa_row1_col7, #T_e0daa_row2_col0, #T_e0daa_row2_col1, #T_e0daa_row2_col2, #T_e0daa_row2_col3, #T_e0daa_row2_col4, #T_e0daa_row2_col5, #T_e0daa_row2_col6, #T_e0daa_row2_col7, #T_e0daa_row4_col1, #T_e0daa_row4_col2, #T_e0daa_row4_col3, #T_e0daa_row4_col4, #T_e0daa_row4_col5, #T_e0daa_row4_col6, #T_e0daa_row4_col7, #T_e0daa_row5_col1, #T_e0daa_row5_col2, #T_e0daa_row5_col3, #T_e0daa_row5_col4, #T_e0daa_row5_col5, #T_e0daa_row5_col6, #T_e0daa_row5_col7, #T_e0daa_row6_col2, #T_e0daa_row6_col7, #T_e0daa_row7_col2, #T_e0daa_row7_col7, #T_e0daa_row8_col1, #T_e0daa_row8_col2, #T_e0daa_row8_col3, #T_e0daa_row8_col4, #T_e0daa_row8_col5, #T_e0daa_row8_col6, #T_e0daa_row8_col7, #T_e0daa_row9_col1, #T_e0daa_row9_col3, #T_e0daa_row9_col4, #T_e0daa_row9_col5, #T_e0daa_row9_col6, #T_e0daa_row10_col1, #T_e0daa_row10_col2, #T_e0daa_row10_col3, #T_e0daa_row10_col4, #T_e0daa_row10_col5, #T_e0daa_row10_col6, #T_e0daa_row10_col7, #T_e0daa_row11_col1, #T_e0daa_row11_col3, #T_e0daa_row11_col4, #T_e0daa_row11_col5, #T_e0daa_row11_col6, #T_e0daa_row11_col7, #T_e0daa_row12_col3, #T_e0daa_row14_col1, #T_e0daa_row14_col3, #T_e0daa_row14_col4, #T_e0daa_row14_col5, #T_e0daa_row14_col6, #T_e0daa_row14_col7, #T_e0daa_row15_col1, #T_e0daa_row15_col2, #T_e0daa_row15_col3, #T_e0daa_row15_col4, #T_e0daa_row15_col5, #T_e0daa_row15_col6, #T_e0daa_row15_col7, #T_e0daa_row17_col1, #T_e0daa_row17_col2, #T_e0daa_row17_col3, #T_e0daa_row17_col4, #T_e0daa_row17_col5, #T_e0daa_row17_col6, #T_e0daa_row17_col7, #T_e0daa_row18_col1, #T_e0daa_row18_col2, #T_e0daa_row18_col3, #T_e0daa_row18_col4, #T_e0daa_row18_col5, #T_e0daa_row18_col6, #T_e0daa_row18_col7, #T_e0daa_row19_col1, #T_e0daa_row19_col2, #T_e0daa_row19_col3, #T_e0daa_row19_col4, #T_e0daa_row19_col5, #T_e0daa_row19_col6, #T_e0daa_row19_col7, #T_e0daa_row20_col1, #T_e0daa_row20_col2, #T_e0daa_row20_col3, #T_e0daa_row20_col4, #T_e0daa_row20_col5, #T_e0daa_row20_col6, #T_e0daa_row20_col7, #T_e0daa_row21_col1, #T_e0daa_row21_col2, #T_e0daa_row21_col3, #T_e0daa_row21_col4, #T_e0daa_row21_col5, #T_e0daa_row21_col6, #T_e0daa_row21_col7, #T_e0daa_row22_col1, #T_e0daa_row22_col2, #T_e0daa_row22_col3, #T_e0daa_row22_col4, #T_e0daa_row22_col5, #T_e0daa_row22_col6, #T_e0daa_row22_col7, #T_e0daa_row23_col1, #T_e0daa_row23_col2, #T_e0daa_row23_col3, #T_e0daa_row23_col4, #T_e0daa_row23_col5, #T_e0daa_row23_col6, #T_e0daa_row23_col7, #T_e0daa_row24_col1, #T_e0daa_row24_col2, #T_e0daa_row24_col3, #T_e0daa_row24_col4, #T_e0daa_row24_col5, #T_e0daa_row24_col6, #T_e0daa_row24_col7, #T_e0daa_row25_col2, #T_e0daa_row25_col7, #T_e0daa_row26_col1, #T_e0daa_row26_col2, #T_e0daa_row26_col3, #T_e0daa_row26_col4, #T_e0daa_row26_col5, #T_e0daa_row26_col6, #T_e0daa_row26_col7, #T_e0daa_row27_col1, #T_e0daa_row27_col2, #T_e0daa_row27_col3, #T_e0daa_row27_col4, #T_e0daa_row27_col5, #T_e0daa_row27_col6, #T_e0daa_row27_col7, #T_e0daa_row28_col1, #T_e0daa_row28_col2, #T_e0daa_row28_col3, #T_e0daa_row28_col4, #T_e0daa_row28_col5, #T_e0daa_row28_col6, #T_e0daa_row28_col7, #T_e0daa_row29_col1, #T_e0daa_row29_col2, #T_e0daa_row29_col3, #T_e0daa_row29_col4, #T_e0daa_row29_col5, #T_e0daa_row29_col6, #T_e0daa_row29_col7, #T_e0daa_row30_col1, #T_e0daa_row30_col2, #T_e0daa_row30_col3, #T_e0daa_row30_col4, #T_e0daa_row30_col5, #T_e0daa_row30_col6, #T_e0daa_row30_col7, #T_e0daa_row31_col1, #T_e0daa_row31_col2, #T_e0daa_row31_col3, #T_e0daa_row31_col4, #T_e0daa_row31_col5, #T_e0daa_row31_col6, #T_e0daa_row31_col7, #T_e0daa_row32_col1, #T_e0daa_row32_col2, #T_e0daa_row32_col3, #T_e0daa_row32_col4, #T_e0daa_row32_col5, #T_e0daa_row32_col6, #T_e0daa_row32_col7, #T_e0daa_row33_col1, #T_e0daa_row33_col2, #T_e0daa_row33_col3, #T_e0daa_row33_col4, #T_e0daa_row33_col5, #T_e0daa_row33_col6, #T_e0daa_row33_col7, #T_e0daa_row34_col1, #T_e0daa_row34_col3, #T_e0daa_row34_col4, #T_e0daa_row34_c ...
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col1, #T_e0daa_row3_col4, #T_e0daa_row3_col5, #T_e0daa_row7_col3, #T_e0daa_row36_col3 {
#   background-color: #08071e;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col2 {
#   background-color: #1d1147;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col3 {
#   background-color: #040414;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col6, #T_e0daa_row6_col3, #T_e0daa_row25_col3 {
#   background-color: #07061c;
#   color: #f1f1f1;
# }
# #T_e0daa_row3_col7 {
#   background-color: #5d177f;
#   color: #f1f1f1;
# }
# #T_e0daa_row6_col1, #T_e0daa_row6_col6, #T_e0daa_row7_col1, #T_e0daa_row7_col6, #T_e0daa_row12_col7, #T_e0daa_row13_col3, #T_e0daa_row16_col1, #T_e0daa_row16_col3, #T_e0daa_row16_col4, #T_e0daa_row16_col5, #T_e0daa_row16_col6, #T_e0daa_row25_col1, #T_e0daa_row25_col6, #T_e0daa_row36_col1, #T_e0daa_row36_col6 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_e0daa_row6_col4, #T_e0daa_row6_col5, #T_e0daa_row7_col4, #T_e0daa_row7_col5, #T_e0daa_row25_col4, #T_e0daa_row25_col5, #T_e0daa_row36_col4, #T_e0daa_row36_col5 {
#   background-color: #010108;
#   color: #f1f1f1;
# }
# #T_e0daa_row8_col0 {
#   background-color: #fcf0b2;
#   color: #000000;
# }
# #T_e0daa_row25_col0 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_e0daa_row34_col7 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e0daa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0daa_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e0daa_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_e0daa_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_e0daa_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_e0daa_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_e0daa_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_e0daa_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_e0daa_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0daa_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_e0daa_row0_col0" class="data row0 col0" >1460.000000</td>
#       <td id="T_e0daa_row0_col1" class="data row0 col1" >730.500000</td>
#       <td id="T_e0daa_row0_col2" class="data ro

# %%
df.info() ## getting the information from the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
var_num = ["SalePrice", "OverallQual", "GrLivArea", "GarageCars", "TotalBsmtSF", "FullBath", "YearBuilt"]
sns.pairplot(df[var_num]);

# %%
sns.distplot(df["SalePrice"])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df["SalePrice"].describe()  ##There is a huge difference between the min and max..
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df["LogSalePrice"] = np.log10(df["SalePrice"])
sns.distplot(df["LogSalePrice"],color = 'r')
# Out:
# <AxesSubplot:xlabel='LogSalePrice', ylabel='Density'>

# %%
## checking if there is any duplicate data

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###### There is no duplicate data

# %%
## Analysing if there is any null values

pd.options.display.max_rows=None ## shows all the rows
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# LogSalePrice        0
# dtype: int64

# %% [markdown]
# ###### We have null values in the dataset
# ###### There are 19 columns with null values

# %%
#pd.reset_option('max_columns')
pd.reset_option('max_rows')

# %% [markdown]
# # Handling the missing values and Feature selection

# %% [markdown]
# ###### Handling missing values for LotFrontage

# %%
df.LotFrontage.value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: LotFrontage, Length: 110, dtype: int64

# %%
## distribution plot for LotFrontage
 
sns.distplot(df.LotFrontage)
plt.show()

# %%
df['LotFrontage'].mean()  ## getting the mean
# Out:
# 70.04995836802665

# %%
## Checking the percentage of missing values for LotFrontage

print('The Percentage of data missing in LotFrontage is ',df.LotFrontage.isnull().sum()/len(df)*100)
# Out:
# The Percentage of data missing in LotFrontage is  17.73972602739726

# %%
df.loc[df['LotFrontage'].isnull()==True]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 7            Lvl    AllPub  ...    NaN    NaN        Shed     350     11
# 12           Lvl    AllPub  ...    NaN    NaN         NaN       0      9
# 14           Lvl    AllPub  ...    NaN   GdWo         NaN       0      5
# 16           Lvl    AllPub  ...    NaN    NaN        Shed     700      3
# 24           Lvl    AllPub  ...    NaN  MnPrv         NaN       0      5
# ...          ...       ...  ...    ...    ...         ...     ...    ...
# 1429         Lvl    AllPub  ...    NaN    NaN         NaN       0      4
# 1431         Lvl    AllPub  ...    NaN    NaN         NaN       0     10
# 1441         Lvl    AllPub  ...    NaN    NaN         NaN       0      5
# 1443         Lvl    AllPub  ...    NaN    NaN         NaN       0      5
# 1446         Lvl    AllPub  ...    NaN    NaN         NaN       0      4
#
#      YrSold SaleType  SaleCondition  SalePrice  LogSalePrice
# 7      2009       WD         Normal     200000      5.301030
# 12     2008       WD         Normal     144000      5.158362
# 14     2008       WD         Normal     157000      5.195900
# 16     2010       WD         Normal     149000      5.173186
# 24     2010       WD         Normal     154000      5.187521
# ...     ...      ...            ...        ...           ...
# 1429   2007       WD         Normal     182900      5.262214
# 1431   2009       WD         Normal     143750      5.157608
# 1441   2008       WD         Normal     149300      5.174060
# 1443   2009       WD         Normal     121000      5.082785
# 1446   2010       WD         Normal     157900      5.198382
#
# [259 rows x 82 columns]

# %%
## Replacing the nan values with mean for LotFrontage

df.loc[df['LotFrontage'].isnull()==True,'LotFrontage']=70.0

# %% [markdown]
# ###### Handling the missing values for Alley,PoolQC,Fence,MiscFeature

# %%
## Percentage of missing values in Alley,PoolQC,Fence,MiscFeature
 
d1=df[['Alley','PoolQC','Fence','MiscFeature']]
a=d1.isnull().sum()/len(d1)*100
a
# Out:
# Alley          93.767123
# PoolQC         99.520548
# Fence          80.753425
# MiscFeature    96.301370
# dtype: float64

# %% [markdown]
# ##### More than 80% of the data are missing in Alley,PoolQC,Fence,MiscFeature

# %%
## removing the features

df.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %% [markdown]
# ###### Handling the missing values for BsmtQual,BsmtQual,BsmtCond,BsmtExposure,BsmtFinType1,BsmtFinType2

# %%
## Percentage of missing values

d2=df[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']]
b=d2.isnull().sum()/len(d2)*100
b
# Out:
# BsmtQual        2.534247
# BsmtCond        2.534247
# BsmtExposure    2.602740
# BsmtFinType1    2.534247
# BsmtFinType2    2.602740
# dtype: float64

# %%
## Replacing the missing values with 'NA'

df['BsmtQual']=df['BsmtQual'].fillna('NA')
df['BsmtCond']=df['BsmtCond'].fillna('NA')
df['BsmtExposure']=df['BsmtExposure'].fillna('NA')
df['BsmtFinType1']=df['BsmtFinType1'].fillna('NA')
df['BsmtFinType2']=df['BsmtFinType2'].fillna('NA')

# %% [markdown]
# ###### Replacing missing values for MasVnrType

# %%
df.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
## Replacing the missing values with mode

df.loc[df['MasVnrType'].isnull()==True,'MasVnrType']='None'

# %%
###### Replacing missing values for MasVnrArea

# %%
 sns.distplot(df.MasVnrArea)
# Out:
# <AxesSubplot:xlabel='MasVnrArea', ylabel='Density'>

# %%
## Finding the median

df['MasVnrArea'].median()
# Out:
# 0.0

# %%
## Replacing the missing value by median
df.loc[df['MasVnrArea'].isnull()==True,'MasVnrArea']=0.0

# %% [markdown]
# ###### Handling missing values for GarageType,GarageFinish,GarageQual,GarageCond

# %%
## Percentage of missing values
d3=df[['GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond' ]]
c=d3.isnull().sum()/len(d3)*100
c
# Out:
# GarageType      5.547945
# GarageYrBlt     5.547945
# GarageFinish    5.547945
# GarageQual      5.547945
# GarageCond      5.547945
# dtype: float64

# %%
## Replacing the missing values for GarageType,GarageFinish,GarageQual,GarageCond  by NA

df['GarageType']=df['GarageType'].fillna('NA')
df['GarageFinish']=df['GarageFinish'].fillna('NA')
df['GarageQual']=df['GarageQual'].fillna('NA')
df['GarageCond']=df['GarageCond'].fillna('NA')

# %% [markdown]
# ###### Handling the missing value for GarageYrBlt

# %%
sns.distplot(df.GarageYrBlt)
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='Density'>

# %%
df.GarageYrBlt.median()
# Out:
# 1980.0

# %%
df.loc[df['GarageYrBlt'].isnull()==True,'GarageYrBlt']=1980.0

# %% [markdown]
# ###### Handling the missing value for Electrical

# %%
df.Electrical.value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
## Replacing the null values with mode
df.loc[df['Electrical'].isnull()==True,'Electrical']='SBrkr'

# %% [markdown]
# ###### Handling the missing values for FireplaceQu

# %%
df.FireplaceQu.value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
## Replacing the missing values with NA
df.loc[df['FireplaceQu'].isnull()==True,'FireplaceQu']='NA'

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# LogSalePrice     0
# Length: 78, dtype: int64

# %% [markdown]
# ###### There is no null values now.We have cleared all the null values.

# %% [markdown]
# **Question 1: What features correlates the most with the Sale Price of the house?**

# %%
## Lets create a list of column names for categorical and numerical features

cate_feat = list(df.select_dtypes(include = [object]).columns)
num_feat = list(df.select_dtypes(include = [int,float]).columns)

print(cate_feat)
print('\n')
print(num_feat)
# Out:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']
#
#
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'LogSalePrice']

# %%
# Heatmap for all the remaining numerical data including the taget 'SalePrice'
# Define the heatmap parameters
pd.options.display.float_format = "{:,.2f}".format

# Define correlation matrix
corr_matrix = df[num_feat].corr()

# Replace correlation < |0.3| by 0 for a better visibility
corr_matrix[(corr_matrix < 0.3) & (corr_matrix > -0.3)] = 0

# plot the heatmap
sns.heatmap(corr_matrix, vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot_kws={"size": 9, "color": "black"},annot=True)
plt.title("SalePrice Correlation")
# Out:
# Text(0.5, 1.0, 'SalePrice Correlation')

# %% [markdown]
# We can see that, The overall quality of the house and Ground living Area has 0.79 and 0.74 correlation with the SalePrice of the house, followed by Garagecars with 0.64 correlation.

# %%
## Lets visualize individually 

corr =df.corr()["SalePrice"].sort_values(ascending = False)[2:8] ## selecting cols other than Saleprice, LogPrice
corr
# Out:
# OverallQual   0.79
# GrLivArea     0.71
# GarageCars    0.64
# GarageArea    0.62
# TotalBsmtSF   0.61
# 1stFlrSF      0.61
# Name: SalePrice, dtype: float64

# %%
f,ax = plt.subplots(nrows = 6,ncols = 1, figsize = (20,40))
for i,col in enumerate(corr.index):    
    sns.scatterplot(x = col, y = "SalePrice", data = df, ax = ax[i], color = 'darkorange')
    ax[i].set_title(f'{col} vs SalePrice')

# %% [markdown]
# We can see the features above are quite linear to the Sale Price suggesting positive correlation

# %% [markdown]
# **Question 1: What year were most of the houses built (Top 10), and does the year built say anything regarding the sale price?**

# %%
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x="YearBuilt", y="SalePrice", data=df,)
fig.axis(ymin=0, ymax=900000);
plt.xticks(rotation=90);
plt.tight_layout()

# %%
yr_built = pd.DataFrame({"Count":df["YearBuilt"].value_counts()[:10]}).reset_index()
yr_built.rename(columns={'index':'Year'},inplace=True)
plt.figure(figsize = (20,10))
sns.barplot(x = 'Year', y = "Count", data = yr_built)
plt.title("Year Built")
# Out:
# Text(0.5, 1.0, 'Year Built')

# %%
## As a side question, lets see if there is a huge difference in sale price based on different months

df.groupby("MoSold").mean()["SalePrice"].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='MoSold'>

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Univarient Analysis

# %%
## Getting the features with object datatype
dtype_objects = list(columns for columns in df.select_dtypes([object]).columns)

# %%
dtype_objects
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
len(dtype_objects)
# Out:
# 39

# %%
## countplot for datatype with objects

plt.figure(figsize=(15,150))
plotnumber=1
for c in dtype_objects:
    ax=plt.subplot(20,2,plotnumber)
    b= sns.countplot(x=df[c],palette='Set2')
    plt.xticks(rotation=70)
    plotnumber+=1
    for bar in b.patches:
        b.annotate(format(bar.get_height()),
            (bar.get_x() + bar.get_width() / 2,
            bar.get_height()), ha='center', va='center',
            size=10, xytext=(0, 6),textcoords='offset points')
plt.show()

# %% [markdown]
# ###### Count plot for the datatype object has been plotted

# %%
## Getting the features with float datatype

dtype_float =list(columns for columns in df.select_dtypes([float]).columns)

# %%
dtype_float
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt', 'LogSalePrice']

# %%
## Distribution plot 

plt.figure(figsize=(15,150))
plotnumber=1
for a in dtype_float:
    ax=plt.subplot(20,2,plotnumber)
    sns.distplot(x=df[a],color='purple')
    plt.xticks(rotation=70)
    plotnumber+=1
plt.show()

# %% [markdown]
# ###### From the graph LotFrontage gives normal distribution but MasVnrArea and GarageYrBlt is skewed

# %%
## Pie plot for CentralAir

plt.figure(figsize=(5,5))
labels=['Y','N']
size=df['CentralAir'].value_counts()
colors=['lightgreen','lightslategray']
explode=[0,0.3]
plt.pie(size,labels=labels,colors=colors,explode=explode,autopct='%.2f%%',shadow = True,startangle = -30,
wedgeprops= {'edgecolor':'white','linewidth':1})
plt.legend(labels,loc="upper right",title='Category') ## used to label at the side
plt.show()

# %% [markdown]
# ###### From the graph 93.49% houses has CentralAir and 6.51% houses has no CentralAir

# %%
## Donut chart for GarageFinish

plt.figure(figsize=(5,5))
labels=['Fin','RFn','Unf','NA']
size=df['GarageFinish'].value_counts()
colors=['purple','lightblue','pink','yellow']
explode=[0,0.1,0,0]
plt.pie(size,labels=labels,colors=colors,explode=explode,autopct='%.2f%%',shadow=True)
circle = plt.Circle( (0,0),0.8, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# ###### From the graph for 41.44% of the houses the interior finish of the garage is finished.

# %% [markdown]
# # **Bivarient and Multivarient Analysis**

# %%
## Countplot for CentralAir and BedroomAbvGr

plt.figure(figsize=(15,9))
sns.countplot(x='CentralAir',hue='BedroomAbvGr',palette='terrain',data=df).set(title="BedroomAbvGr vs CentralAir")
plt.show()

# %% [markdown]
# ### The houses with 3 bedrooms has more central air conditioning than others.

# %%
## Scatter plot for GarageArea and GarageYrBlt

sns.scatterplot(x='GarageArea',y='GarageYrBlt',data=df,color='lightcoral')
plt.show()

# %% [markdown]
# **We can see there are some outliers present while comparing garage area and garage year built**

# %%
data=df

# %%
## barplot for saleprice and the data type with objects

plt.figure(figsize=(20,150),facecolor='white')
plotnumber=1
for c in dtype_objects:
    ax=plt.subplot(20,2,plotnumber)
    sns.barplot(x=data[c],y=data.SalePrice,palette='Set3')
    plotnumber+=1
    plt.xticks(rotation=70)
plt.show()

# %%
## bar plot for Electrical,MSSubClass,CentralAir

plt.figure(figsize=(15,9))
splot=sns.barplot(x='Electrical',y='MSSubClass',hue='CentralAir',palette='nipy_spectral',data=data)
plt.show()

# %% [markdown]
# **Building with 2-STORY 1946 & NEWER and Standard Circuit Breakers & Romex use more central air conditioning than others.**

# %%
## Getting the continuous data features

box=df[['LotArea','YearBuilt','BsmtFinSF1','1stFlrSF','2ndFlrSF','LotFrontage', 'MasVnrArea', 'GarageYrBlt']]

# %%
plt.figure(figsize=(15,15),facecolor='white')

plotnum=1 #counter

for c in box:
    if(plotnum<9):
        a=plt.subplot(4,2,plotnum)#plotting 8 graph
        sns.distplot(box[c])#to know distribution
    plotnum+=1#increment counter
plt.tight_layout()

# %% [markdown]
# # Finding the outliers

# %%
## getting the continuous data features

box=df[['LotArea','YearBuilt','BsmtFinSF1','1stFlrSF','2ndFlrSF','LotFrontage', 'MasVnrArea', 'GarageYrBlt']]

# %%
box
# Out:
#       LotArea  YearBuilt  BsmtFinSF1  1stFlrSF  2ndFlrSF  LotFrontage  \
# 0        8450       2003         706       856       854        65.00
# 1        9600       1976         978      1262         0        80.00
# 2       11250       2001         486       920       866        68.00
# 3        9550       1915         216       961       756        60.00
# 4       14260       2000         655      1145      1053        84.00
# ...       ...        ...         ...       ...       ...          ...
# 1455     7917       1999           0       953       694        62.00
# 1456    13175       1978         790      2073         0        85.00
# 1457     9042       1941         275      1188      1152        66.00
# 1458     9717       1950          49      1078         0        68.00
# 1459     9937       1965         830      1256         0        75.00
#
#       MasVnrArea  GarageYrBlt
# 0         196.00     2,003.00
# 1           0.00     1,976.00
# 2         162.00     2,001.00
# 3           0.00     1,998.00
# 4         350.00     2,000.00
# ...          ...          ...
# 1455        0.00     1,999.00
# 1456      119.00     1,978.00
# 1457        0.00     1,941.00
# 1458        0.00     1,950.00
# 1459        0.00     1,965.00
#
# [1460 rows x 8 columns]

# %%
## boxplot to find the outliers

plt.figure(figsize=(10,30),facecolor='white')
plotnumber=1
for c in box:
    ax=plt.subplot(8,1,plotnumber)
    sns.boxplot(data[c],color='green')
    plotnumber=plotnumber + 1 
plt.show()

# %% [markdown]
# # Handling the skewness

# %%
from scipy.stats import skew

numerical_features = data.dtypes[data.dtypes != 'object'].index

# checking the skewness in all the numerical features
skewed_features = df[numerical_features].apply(lambda x: skew(x.dropna())).sort_values(ascending = False)

# converting the features into a dataframe
skewness = pd.DataFrame({'skew':skewed_features})

# checking the head of skewness dataset
skewness
# Out:
#                skew
# MiscVal       24.45
# PoolArea      14.81
# LotArea       12.20
# 3SsnPorch     10.29
# LowQualFinSF   9.00
# KitchenAbvGr   4.48
# BsmtFinSF2     4.25
# ScreenPorch    4.12
# BsmtHalfBath   4.10
# EnclosedPorch  3.09
# MasVnrArea     2.67
# LotFrontage    2.38
# OpenPorchSF    2.36
# SalePrice      1.88
# BsmtFinSF1     1.68
# WoodDeckSF     1.54
# TotalBsmtSF    1.52
# MSSubClass     1.41
# 1stFlrSF       1.38
# GrLivArea      1.37
# BsmtUnfSF      0.92
# 2ndFlrSF       0.81
# OverallCond    0.69
# TotRmsAbvGrd   0.68
# HalfBath       0.68
# Fireplaces     0.65
# BsmtFullBath   0.60
# OverallQual    0.22
# MoSold         0.21
# BedroomAbvGr   0.21
# GarageArea     0.18
# LogSalePrice   0.12
# YrSold         0.10
# FullBath       0.04
# Id             0.00
# GarageCars    -0.34
# YearRemodAdd  -0.50
# YearBuilt     -0.61
# GarageYrBlt   -0.68

# %%
##applying box-cox transformations

skewness = skewness[abs(skewness > 0.8)]

# printing how many features are to be box-cox transformed
print("There are {} skewed numerical features to box cox transform".format(skewness.shape[0]))

# importing box-cox1p
from scipy.special import boxcox1p

# defining skewed features
skewed_features = skewness.index

lamda = 0.15
for features in skewed_features:
    df[features] += 1
    df[features] = boxcox1p(df[features], lamda)
df[skewed_features] = np.log1p(df[skewed_features])
print('Skewness has been Handled using Box Cox Transformation')
# Out:
# There are 39 skewed numerical features to box cox transform
# Skewness has been Handled using Box Cox Transformation

# %% [markdown]
# ### Changing categorical data to numerical data

# %%
#getting all the categorical feature

data_object = df.select_dtypes(include = "object").columns
print (data_object)
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
#Label Encoding to convert categorical data to numerical data

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for features in data_object:
    df[features] = le.fit_transform(df[features].astype(str))

print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   float64
#  1   MSSubClass     1460 non-null   float64
#  2   MSZoning       1460 non-null   int32
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   float64
#  5   Street         1460 non-null   int32
#  6   LotShape       1460 non-null   int32
#  7   LandContour    1460 non-null   int32
#  8   Utilities      1460 non-null   int32
#  9   LotConfig      1460 non-null   int32
#  10  LandSlope      1460 non-null   int32
#  11  Neighborhood   1460 non-null   int32
#  12  Condition1     1460 non-null   int32
#  13  Condition2     1460 non-null   int32
#  14  BldgType       1460 non-null   int32
#  15  HouseStyle     1460 non-null   int32
#  16  OverallQual    1460 non-null   float64
#  17  OverallCond    1460 non-null   float64
#  18  YearBuilt      1460 non-null   float64
#  19  YearRemodAdd   1460 non-null   float64
#  20  RoofStyle      1460 non-null   int32
#  21  RoofMatl       1460 non-null   int32
#  22  Exterior1st    1460 non-null   int32
#  23  Exterior2nd    1460 non-null   int32
#  24  MasVnrType     1460 non-null   int32
#  25  MasVnrArea     1460 non-null   float64
#  26  ExterQual      1460 non-null   int32
#  27  ExterCond      1460 non-null   int32
#  28  Foundation     1460 non-null   int32
#  29  BsmtQual       1460 non-null   int32
#  30  BsmtCond       1460 non-null   int32
#  31  BsmtExposure   1460 non-null   int32
#  32  BsmtFinType1   1460 non-null   int32
#  33  BsmtFinSF1     1460 non-null   float64
#  34  BsmtFinType2   1460 non-null   int32
#  35  BsmtFinSF2     1460 non-null   float64
#  36  BsmtUnfSF      1460 non-null   float64
#  37  TotalBsmtSF    1460 non-null   float64
#  38  Heating        1460 non-null   int32
#  39  HeatingQC      1460 non-null   int32
#  40  CentralAir     1460 non-null   int32
#  41  Electrical     1460 non-null   int32
#  42  1stFlrSF       1460 non-null   float64
#  43  2ndFlrSF       1460 non-null   float64
#  44  LowQualFinSF   1460 non-null   float64
#  45  GrLivArea      1460 non-null   float64
#  46  BsmtFullBath   1460 non-null   float64
#  47  BsmtHalfBath   1460 non-null   float64
#  48  FullBath       1460 non-null   float64
#  49  HalfBath       1460 non-null   float64
#  50  BedroomAbvGr   1460 non-null   float64
#  51  KitchenAbvGr   1460 non-null   float64
#  52  KitchenQual    1460 non-null   int32
#  53  TotRmsAbvGrd   1460 non-null   float64
#  54  Functional     1460 non-null   int32
#  55  Fireplaces     1460 non-null   float64
#  56  FireplaceQu    1460 non-null   int32
#  57  GarageType     1460 non-null   int32
#  58  GarageYrBlt    1460 non-null   float64
#  59  GarageFinish   1460 non-null   int32
#  60  GarageCars     1460 non-null   float64
#  61  GarageArea     1460 non-null   float64
#  62  GarageQual     1460 non-null   int32
#  63  GarageCond     1460 non-null   int32
#  64  PavedDrive     1460 non-null   int32
#  65  WoodDeckSF     1460 non-null   float64
#  66  OpenPorchSF    1460 non-null   float64
#  67  EnclosedPorch  1460 non-null   float64
#  68  3SsnPorch      1460 non-null   float64
#  69  ScreenPorch    1460 non-null   float64
#  70  PoolArea       1460 non-null   float64
#  71  MiscVal        1460 non-null   float64
#  72  MoSold         1460 non-null   float64
#  73  YrSold         1460 non-null   float64
#  74  SaleType       1460 non-null   int32
#  75  SaleCondition  1460 non-null   int32
#  76  SalePrice      1460 non-null   float64
#  77  LogSalePrice   1460 non-null   float64
# dtypes: float64(39), int32(39)
# memory usage: 667.4 KB
# None

# %% [markdown]
# # Feature Scaling

# %%
## Scaling the features
## Spliting the variables

x=df.drop(['Id','SalePrice'],axis=1) ## all the features
y=df['SalePrice']  ## target variable

# %%
#using minmax scaler to scale all the datas

from sklearn.preprocessing import MinMaxScaler
mc=MinMaxScaler()
scaled_x=mc.fit_transform(x)

# %% [markdown]
# ## **Model Creation**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(scaled_x,y,test_size=0.20,random_state=0)

print("Traning Shape = ",x_train.shape)  ## number of rows and columns  given for training
print('Testing Shape = ',x_test.shape)  ## number of row and columns given for testing
# Out:
# Traning Shape =  (1168, 76)
# Testing Shape =  (292, 76)

# %% [markdown]
# # **Model Evaluation**
# ## Linear Regression

# %%
## importing the library

from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)  ## fitting the training data

x_test_pred_LR=LR.predict(x_test)  ## predicted x test

# %%
x_test_pred_LR
# Out:
# array([3.58225096, 3.51073145, 3.47679707, 3.57476195, 3.43600779,
#        3.43058714, 3.64094753, 3.5206022 , 3.79807657, 3.5305856 ,
#        3.58903708, 3.5133536 , 3.60258812, 3.49633842, 3.49144597,
#        3.52558075, 3.57358263, 3.49816668, 3.53052435, 3.53754812,
#        3.55020587, 3.52578819, 3.47791423, 3.55743616, 3.56887349,
#        3.55205181, 3.56134753, 3.42981331, 3.66393621, 3.49095835,
#        3.47625511, 3.59310777, 3.53806694, 3.62039416, 3.68710741,
#        3.55840556, 3.63922834, 3.48062436, 3.62837988, 3.66478797,
#        3.61418271, 3.50589042, 3.54898038, 3.63996597, 3.69948546,
#        3.48975852, 3.4984038 , 3.50357549, 3.55653948, 3.43066761,
#        3.70460304, 3.53847227, 3.55165969, 3.46097382, 3.63578788,
#        3.49694587, 3.51018815, 3.6128836 , 3.51817865, 3.48449789,
#        3.51651608, 3.5130942 , 3.51238947, 3.56367854, 3.576521  ,
#        3.5396283 , 3.50907391, 3.60121882, 3.51841819, 3.60235501,
#        3.57183799, 3.48859701, 3.4261631 , 3.69480319, 3.48052507,
#        3.6196079 , 3.51211506, 3.41723619, 3.66106128, 3.54063465,
#        3.51968591, 3.51480323, 3.47367356, 3.52540617, 3.58330729,
#        3.56853036, 3.46915173, 3.58428319, 3.56883095, 3.51400697,
#        3.58197672, 3.5732347 , 3.57032333, 3.5820461 , 3.55671323,
#        3.53978034, 3.59289366, 3.56884069, 3.49859192, 3.54665398,
#        3.62669112, 3.58083639, 3.49267123, 3.54201851, 3.46974523,
#        3.62686928, 3.52342785, 3.47185377, 3.56278908, 3.50300373,
#        3.44216226, 3.49031176, 3.5731773 , 3.49263031, 3.56788549,
#        3.53758586, 3.69443526, 3.51003422, 3.57624159, 3.63328498,
#        3.52176262, 3.52741305, 3.50474689, 3.55987565, 3.59371236,
#        3.60237066, 3.70620579, 3.57107938, 3.5815039 , 3.56389733,
#        3.58655178, 3.57688864, 3.52320004, 3.5671103 , 3.48609073,
#        3.59276365, 3.51912756, 3.56206986, 3.47270847, 3.56013216,
#        3.54088625, 3.52529047, 3.59665578, 3.53263878, 3.47602014,
#        3.54923136, 3.58293527, 3.52640004, 3.6628148 , 3.59455786,
#        3.56401991, 3.68584135, 3.61270037, 3.5272529 , 3.544049  ,
#        3.61970337, 3.44031593, 3.60581192, 3.52862692, 3.5475291 ,
#        3.45428062, 3.52285533, 3.5790118 , 3.50543716, 3.60722735,
#        3.48720813, 3.55803355, 3.62990626, 3.58819454, 3.56426177,
#        3.55914497, 3.55469179, 3.57908874, 3.56002077, 3.48199834,
#        3.51780048, 3.51295809, 3.61231267, 3.48095765, 3.51099515,
#        3.65972831, 3.55348944, 3.48708539, 3.65452174, 3.42484538,
#        3.55935351, 3.46986325, 3.57740589, 3.57683318, 3.53876757,
#        3.51674588, 3.56025968, 3.59342424, 3.52962561, 3.50260996,
#        3.5224877 , 3.41902802, 3.5251579 , 3.55461271, 3.49566756,
#        3.51845689, 3.57227109, 3.49266637, 3.49949288, 3.54277418,
#        3.58131563, 3.54309249, 3.65903763, 3.63622931, 3.38869548,
#        3.54151077, 3.62105561, 3.44712886, 3.4768337 , 3.69381325,
#        3.50666359, 3.42493551, 3.65111192, 3.61987674, 3.42211709,
#        3.57056585, 3.47670268, 3.48759844, 3.50414204, 3.59293721,
#        3.64186131, 3.60608134, 3.57323038, 3.51282637, 3.5342849 ,
#        3.43620601, 3.53774819, 3.48567275, 3.52391863, 3.61911399,
#        3.50989226, 3.51456984, 3.48780673, 3.42611018, 3.54038563,
#        3.47706617, 3.56391503, 3.57558134, 3.60101256, 3.56473762,
#        3.55334188, 3.57164471, 3.5691913 , 3.54356825, 3.57502938,
#        3.56520606, 3.63073228, 3.45997533, 3.71487911, 3.60597829,
#        3.59597512, 3.47806699, 3.56000212, 3.74814591, 3.54600285,
#        3.55699013, 3.47378385, 3.50927471, 3.47244769, 3.69371869,
#        3.68840994, 3.67442007, 3.39041045, 3.62015376, 3.61709831,
#        3.49964404, 3.60901986, 3.5263513 , 3.56464162, 3.46661316,
#        3.60795847, 3.54740859, 3.59708735, 3.57765169, 3.47415648,
#        3.53102064, 3.65994755, 3.56043129, 3.51957543, 3.57679587,
#        3.51812949, 3.4886859 , 3.66403045, 3.75340968, 3.51653599,
#        3.42685599, 3.46226559])

# %%
y_test ## tested y
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
x_train_pred_LR=LR.predict(x_train) ##predicted x train

x_train_pred_LR
# Out:
# array([3.66059537, 3.47663109, 3.54662469, ..., 3.47932418, 3.60831821,
#        3.59878531])

# %%
y_train  ## trained y
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %%
print('Linear Regression trainind score is',LR.score(x_train,y_train))
# Out:
# Linear Regression trainind score is 0.9998270692514184

# %%
print('Linear Regression testing score is',LR.score(x_test,y_test))
# Out:
# Linear Regression testing score is 0.9997997133114862

# %% [markdown]
# # Evaluation Metrics for Linear Regression

# %%
from sklearn.metrics import r2_score
train_score=r2_score(y_train,x_train_pred_LR)
print('Linear Regression r2_score for training is',train_score)
# Out:
# Linear Regression r2_score for training is 0.9998270692514184

# %%
test_score=r2_score(y_test,x_test_pred_LR)
print('Linear Regression r2_score for testing is',test_score)
# Out:
# Linear Regression r2_score for testing is 0.9997997133114862

# %% [markdown]
# #### Training score is more than testing score so the model is underfitting.

# %% [markdown]
# # Random Forest Regressor

# %%
## Importing the library

from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()
RF.fit(x_train,y_train) ## fitting the data

x_test_pred_RF=RF.predict(x_test)  ## predicted x test

# %%
x_test_pred_RF
# Out:
# array([3.58217771, 3.51038157, 3.47705502, 3.57467167, 3.43718903,
#        3.43180496, 3.64219304, 3.52095616, 3.77575318, 3.53022727,
#        3.58907731, 3.51549616, 3.60191639, 3.49673168, 3.49077049,
#        3.52554696, 3.57263683, 3.49771197, 3.53074395, 3.53713137,
#        3.54898406, 3.52490956, 3.47700153, 3.55728585, 3.56803817,
#        3.55126448, 3.56106351, 3.4309771 , 3.66228921, 3.49004938,
#        3.47706385, 3.59263917, 3.53840497, 3.62010362, 3.69010232,
#        3.55830068, 3.63860798, 3.48099158, 3.62889598, 3.66605044,
#        3.6161108 , 3.50638572, 3.54803018, 3.6396133 , 3.70206131,
#        3.49078535, 3.49944129, 3.50378048, 3.55588158, 3.43157738,
#        3.70606235, 3.53834001, 3.55123417, 3.46009576, 3.6365292 ,
#        3.4967145 , 3.50899329, 3.6130667 , 3.51807708, 3.48465944,
#        3.51629097, 3.51298669, 3.51246515, 3.56393389, 3.57619576,
#        3.53946913, 3.50901774, 3.60188947, 3.51804538, 3.60194643,
#        3.57170398, 3.48943134, 3.42513355, 3.69863768, 3.4802541 ,
#        3.61922824, 3.51246159, 3.42050651, 3.66223567, 3.54045815,
#        3.51936037, 3.5150061 , 3.47264397, 3.52554317, 3.58175419,
#        3.56805884, 3.46875812, 3.58375387, 3.56893423, 3.51408933,
#        3.58174191, 3.57266349, 3.57050063, 3.58163703, 3.55573096,
#        3.53950974, 3.59266908, 3.56807616, 3.49876748, 3.5459696 ,
#        3.62701526, 3.58023372, 3.49225515, 3.54204815, 3.46996097,
#        3.62701509, 3.52310433, 3.47196195, 3.56227858, 3.50222828,
#        3.44109392, 3.49009898, 3.57266257, 3.49237623, 3.56704952,
#        3.53723644, 3.6932963 , 3.5103072 , 3.57631323, 3.63319601,
#        3.52067491, 3.52691652, 3.50435411, 3.55948244, 3.59313327,
#        3.59970517, 3.70858651, 3.57083081, 3.581564  , 3.56320887,
#        3.5866305 , 3.57667114, 3.52314036, 3.56629963, 3.48684736,
#        3.59278893, 3.51891148, 3.56238536, 3.47372784, 3.55946553,
#        3.5416233 , 3.52559112, 3.59577482, 3.53258891, 3.47511632,
#        3.54850719, 3.58229628, 3.52607778, 3.66214059, 3.59419312,
#        3.56394188, 3.68830189, 3.61251104, 3.52678217, 3.54412147,
#        3.62013058, 3.44084434, 3.60583744, 3.52779572, 3.54708272,
#        3.45521425, 3.52188819, 3.57889391, 3.50499461, 3.60740683,
#        3.48475936, 3.55834241, 3.63034341, 3.58776224, 3.56419396,
#        3.55939464, 3.55446493, 3.57821108, 3.5593611 , 3.48115958,
#        3.51806781, 3.51295938, 3.6130387 , 3.48027735, 3.51151223,
#        3.66117264, 3.55315846, 3.48685628, 3.65517262, 3.42650716,
#        3.55831361, 3.47029623, 3.57671862, 3.57674582, 3.53812347,
#        3.51696513, 3.5602497 , 3.59315327, 3.52924846, 3.50216849,
#        3.522419  , 3.42056524, 3.52558545, 3.55450808, 3.49616298,
#        3.51808579, 3.57165959, 3.49306616, 3.49804444, 3.54276762,
#        3.58159153, 3.54273423, 3.65867107, 3.63668468, 3.38103662,
#        3.54169937, 3.62057139, 3.44795292, 3.47624443, 3.69157443,
#        3.50490008, 3.42643345, 3.65278676, 3.62023548, 3.42229206,
#        3.57029007, 3.477091  , 3.48735035, 3.50435224, 3.59293138,
#        3.6424022 , 3.6058324 , 3.57264376, 3.51299971, 3.5337145 ,
#        3.43720991, 3.53718532, 3.48472843, 3.5243257 , 3.61933015,
#        3.50983441, 3.51422037, 3.48753131, 3.42509427, 3.54019264,
#        3.47693361, 3.56409787, 3.57496735, 3.60111665, 3.56448342,
#        3.55327924, 3.57038395, 3.56887379, 3.54278695, 3.57467529,
#        3.56463562, 3.63099951, 3.46013855, 3.72021262, 3.60490817,
#        3.59555675, 3.4777698 , 3.55933712, 3.76121157, 3.54268982,
#        3.55589204, 3.47370422, 3.50844843, 3.47104137, 3.69267366,
#        3.68863663, 3.67638747, 3.38744133, 3.62033437, 3.61686901,
#        3.49944547, 3.60863503, 3.52557823, 3.56415027, 3.46590569,
#        3.60814613, 3.54711813, 3.59772066, 3.576951  , 3.47374593,
#        3.53130801, 3.66032155, 3.56109929, 3.51934845, 3.57671681,
#        3.51685813, 3.489418  , 3.66623178, 3.76462273, 3.51410087,
#        3.42673715, 3.46424668])

# %%
y_test   ## y test
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
x_train_pred_RF=LR.predict(x_train)  ## predicted x train
x_train_pred_RF
# Out:
# array([3.66059537, 3.47663109, 3.54662469, ..., 3.47932418, 3.60831821,
#        3.59878531])

# %%
y_train  ## y train
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %% [markdown]
# ### Random Foresr Regressor Score

# %%
print('Training score for Random Forest Regressor is',RF.score(x_train,y_train))
# Out:
# Training score for Random Forest Regressor is 0.9998768048545722

# %%
print('Testing score for Random Forest Regressor is',RF.score(x_test,y_test))
# Out:
# Testing score for Random Forest Regressor is 0.9990548341820235

# %% [markdown]
# Testing score for Random Forest Regressor is 0.8734354150958835

# %% [markdown]
# **Training score is more than Testing score,so the Random Forest Regressor model is underfitting.So we can do hyper parametric tuning.**

# %% [markdown]
# # Hyper parametric Tuning -- Random Forest Regressor

# %%
from sklearn.model_selection import RandomizedSearchCV

random_grid = {'n_estimators': [100,200,300,400,500,600],  ## no. of trees
               'max_features': ['auto', 'sqrt'],  
               'max_depth': [10, 15,20,25], ## maxinum number of levels in trees 
               'min_samples_split':  [2, 5, 10], ## minimum number of samples required to split a node
               'min_samples_leaf': [1, 2, 4], ## Minimum number of samples required at each leaf node
               'bootstrap': [True, False]}  ##  Method of selecting samples for training each tree

# %%
hyper_tuning=RandomizedSearchCV(estimator=RF,param_distributions=random_grid,n_iter=10,cv=5,verbose=5,random_state=2)

# %%
hyper_tuning.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.956 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.901 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.911 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.937 total time=   0.9s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.943 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.959 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.902 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.917 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.941 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.945 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.999 total time=   2.5s
# [CV 2/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.994 total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.996 total time=   2.5s
# [CV 4/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.996 total time=   2.5s
# [CV 5/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=1.000 total time=   2.6s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.999 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.994 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.997 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.995 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.955 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.896 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.909 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.937 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.941 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.999 total time=   2.0s
# [CV 2/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.998 total time=   1.9s
# [CV 3/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.998 total time=   1.8s
# [CV 4/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.995 total time=   1.8s
# [CV 5/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=1.000 total time=   1.9s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.963 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.901 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.917 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.940 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.944 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.961 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.908 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.919 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.945 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.950 total time=   0.9s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.956 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.900 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.911 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.937 total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.943 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=1.000 total time=   2.3s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.999 total time=   2.1s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.999 total time=   2.1s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.998 total time=   2.0s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=1.000 total time=   2.1s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 15, 20, 25],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600]},
#                    random_state=2, verbose=5)

# %%
hyper_tuning.best_params_  ## getting the best parameters
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 10,
#  'bootstrap': False}

# %%
RF_hyper_tuning=RandomForestRegressor(n_estimators=600,min_samples_split=2,min_samples_leaf= 1,max_features='sqrt',max_depth=30,bootstrap= False)  ## implementing the best parameters

# %%
RF_hyper_tuning.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=30, max_features='sqrt',
#                       n_estimators=600)

# %%
RF_hyper_pred_test=RF_hyper_tuning.predict(x_test) ## predicted hyperparametric tuning x test

RF_hyper_pred_test
# Out:
# array([3.59225534, 3.51538935, 3.48014724, 3.57894663, 3.44288488,
#        3.45292375, 3.62355513, 3.509307  , 3.74480139, 3.53202024,
#        3.58828249, 3.52327361, 3.6027365 , 3.50266955, 3.49669112,
#        3.52351096, 3.58693175, 3.48146873, 3.52544606, 3.53789013,
#        3.51883053, 3.52532922, 3.47081179, 3.55336847, 3.57318583,
#        3.56436676, 3.55788407, 3.42507463, 3.66278514, 3.48965189,
#        3.50155217, 3.58654486, 3.52766071, 3.63530513, 3.67557263,
#        3.56151797, 3.63712965, 3.48902806, 3.61563348, 3.65838285,
#        3.6022464 , 3.50870309, 3.55622244, 3.64830182, 3.67669289,
#        3.50753247, 3.50213398, 3.50521588, 3.5543323 , 3.45166202,
#        3.69040256, 3.5320467 , 3.55026787, 3.43599614, 3.62307867,
#        3.49042014, 3.50240198, 3.60955831, 3.51780568, 3.47845713,
#        3.52260521, 3.51188473, 3.52024415, 3.55024554, 3.58431349,
#        3.53781058, 3.50580565, 3.5997073 , 3.51298202, 3.5896861 ,
#        3.56641833, 3.49347291, 3.43434228, 3.61950825, 3.46009287,
#        3.62336063, 3.51237221, 3.45489773, 3.64753584, 3.53908728,
#        3.51588643, 3.51175357, 3.48383653, 3.52462742, 3.57241423,
#        3.57175672, 3.46960492, 3.58166216, 3.56661199, 3.51672739,
#        3.57833818, 3.56781098, 3.56721817, 3.58967097, 3.57235026,
#        3.53643442, 3.5920315 , 3.55672334, 3.49866631, 3.53357861,
#        3.62353017, 3.58199085, 3.49814982, 3.53871279, 3.4774234 ,
#        3.62917436, 3.53159947, 3.46613035, 3.56056602, 3.48686673,
#        3.44769459, 3.49279467, 3.57355168, 3.49284425, 3.55428438,
#        3.5353792 , 3.70173876, 3.50852108, 3.57795975, 3.62620446,
#        3.50229278, 3.5414169 , 3.50812291, 3.56963166, 3.59759642,
#        3.60961271, 3.69488294, 3.57480991, 3.5790775 , 3.55729059,
#        3.58346988, 3.58069312, 3.51457974, 3.56805586, 3.48028972,
#        3.60115954, 3.51554316, 3.56457507, 3.47616857, 3.56423634,
#        3.53101705, 3.52326699, 3.59890238, 3.52857537, 3.49654095,
#        3.55656675, 3.59370888, 3.52315052, 3.64477761, 3.60298611,
#        3.5575166 , 3.68823869, 3.62289222, 3.53033489, 3.53989842,
#        3.61877647, 3.47861024, 3.57360731, 3.48800901, 3.55025175,
#        3.48011469, 3.52213119, 3.57532692, 3.4997747 , 3.61174906,
#        3.48372853, 3.55317433, 3.63922037, 3.58233602, 3.56100107,
#        3.55882898, 3.54603993, 3.57971166, 3.55527843, 3.48639108,
#        3.50192398, 3.51250603, 3.60891217, 3.48393477, 3.51802224,
#        3.63548993, 3.56227192, 3.48042829, 3.65454265, 3.46586803,
#        3.55954211, 3.46410403, 3.57856118, 3.58158613, 3.52630449,
#        3.52138382, 3.55047851, 3.59134481, 3.52383268, 3.50222553,
#        3.52194566, 3.430179  , 3.5202906 , 3.55135813, 3.49834685,
#        3.5135283 , 3.57545726, 3.48541863, 3.4877591 , 3.51853337,
#        3.56691549, 3.53785992, 3.65988603, 3.62978257, 3.39013788,
#        3.53594489, 3.6224881 , 3.44509939, 3.45950239, 3.669818  ,
#        3.54704632, 3.53039452, 3.63412201, 3.61785723, 3.43071917,
#        3.57312671, 3.50810895, 3.49509006, 3.50112149, 3.58479828,
#        3.63744917, 3.60747313, 3.58450205, 3.5142366 , 3.54183063,
#        3.44668887, 3.52324839, 3.4722848 , 3.52259467, 3.60954108,
#        3.50524205, 3.51366969, 3.49166685, 3.43967456, 3.54685644,
#        3.47522339, 3.5674209 , 3.5802296 , 3.6007159 , 3.5571116 ,
#        3.54387988, 3.57347528, 3.56813272, 3.52382014, 3.57609601,
#        3.56017588, 3.62780067, 3.44688964, 3.69069306, 3.6025465 ,
#        3.60275742, 3.46431943, 3.5772952 , 3.70086159, 3.61075478,
#        3.56750118, 3.48906439, 3.50677766, 3.46330922, 3.69989116,
#        3.67618202, 3.65687123, 3.40156157, 3.58588266, 3.61705973,
#        3.50198107, 3.59455179, 3.51789169, 3.56227846, 3.48192824,
#        3.60685735, 3.57182573, 3.57196039, 3.58654353, 3.47059249,
#        3.51882066, 3.67639591, 3.54763274, 3.51737927, 3.5779895 ,
#        3.52072555, 3.48599819, 3.64424719, 3.72146149, 3.52637913,
#        3.41061896, 3.45799897])

# %%
RF_hyper_pred_train=RF_hyper_tuning.predict(x_train)  ## predicted hyper parametric tuning x train

RF_hyper_pred_train
# Out:
# array([3.65995718, 3.47620275, 3.54651016, ..., 3.48018103, 3.60880129,
#        3.5989052 ])

# %% [markdown]
# ### Score after Random Forest Regressor Hyper Parametric Tuning

# %%
print('Training score for Random Forest Regressor Hyper Parametric Tuning is ',RF_hyper_tuning.score(x_train,y_train))
# Out:
# Training score for Random Forest Regressor Hyper Parametric Tuning is  1.0

# %%
print('Testing score for Random Forest Regressor Hyper Parametric Tuning is ',RF_hyper_tuning.score(x_test,y_test))
# Out:
# Testing score for Random Forest Regressor Hyper Parametric Tuning is  0.9510584210495266

# %% [markdown]
# # Decision Tree Regressor

# %%
## Importing the library

from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
x_test_pred_DT=DT.predict(x_test) ## predicted x test

x_test_pred_DT  ## predicted x test
# Out:
# array([3.58245295, 3.51039005, 3.47700581, 3.57539744, 3.43755724,
#        3.43140396, 3.64223346, 3.52062772, 3.77697651, 3.53028646,
#        3.58964119, 3.51545753, 3.60201225, 3.49666629, 3.49085334,
#        3.52552538, 3.57267414, 3.49666629, 3.53110617, 3.53707514,
#        3.548526  , 3.52540463, 3.47700581, 3.55736315, 3.56803594,
#        3.55124641, 3.56034098, 3.43035675, 3.66168819, 3.49011267,
#        3.47700581, 3.59169864, 3.53831148, 3.62023614, 3.68762393,
#        3.55836156, 3.63978958, 3.48174689, 3.63094575, 3.66700678,
#        3.61603821, 3.5063872 , 3.54810359, 3.63948159, 3.70186485,
#        3.49080012, 3.49950045, 3.50366565, 3.5557534 , 3.43140396,
#        3.70186485, 3.53831148, 3.55114258, 3.46018513, 3.63662134,
#        3.49666629, 3.50906614, 3.61318051, 3.51812521, 3.48483639,
#        3.51622398, 3.51300751, 3.51235689, 3.56375046, 3.57494658,
#        3.5394277 , 3.50906614, 3.60193526, 3.51812521, 3.60201225,
#        3.57175657, 3.48936878, 3.42284307, 3.69869497, 3.48018103,
#        3.61907676, 3.51235689, 3.42041256, 3.66276545, 3.54042608,
#        3.51938105, 3.51494465, 3.47278827, 3.52552538, 3.5816737 ,
#        3.56803594, 3.46963942, 3.58374381, 3.5685055 , 3.51397882,
#        3.5816737 , 3.57267414, 3.57037087, 3.58158689, 3.5557534 ,
#        3.5394277 , 3.59169864, 3.56803594, 3.49879629, 3.54597569,
#        3.62634366, 3.58150004, 3.49232516, 3.54163843, 3.46963942,
#        3.62634366, 3.5230941 , 3.4713039 , 3.56229762, 3.50228848,
#        3.43956054, 3.49011267, 3.57267414, 3.49232516, 3.5670929 ,
#        3.53718791, 3.69223653, 3.51039005, 3.57539744, 3.63352023,
#        3.52062772, 3.52672816, 3.50435011, 3.55984828, 3.5933268 ,
#        3.59929672, 3.70523322, 3.57083403, 3.58150004, 3.56317081,
#        3.58671814, 3.57539744, 3.5230941 , 3.56614461, 3.48787125,
#        3.59292123, 3.51887982, 3.56229762, 3.47278827, 3.55935415,
#        3.54163843, 3.52552538, 3.59534025, 3.53232839, 3.47540885,
#        3.548526  , 3.58245295, 3.52582687, 3.66276545, 3.59413505,
#        3.56375046, 3.68877845, 3.61173334, 3.52732638, 3.54382086,
#        3.62023614, 3.44055353, 3.60502548, 3.52792252, 3.54704296,
#        3.45480059, 3.52248084, 3.57896187, 3.50503183, 3.60818647,
#        3.48483639, 3.55836156, 3.63094575, 3.58671814, 3.56519099,
#        3.55978116, 3.55433226, 3.57807775, 3.55984828, 3.48174689,
#        3.51812521, 3.51300751, 3.61318051, 3.48018103, 3.51131073,
#        3.66046796, 3.55330985, 3.48787125, 3.6545126 , 3.42824311,
#        3.55836156, 3.46880109, 3.57539744, 3.57494658, 3.5381266 ,
#        3.51686008, 3.56034098, 3.5933268 , 3.52910858, 3.50228848,
#        3.52186536, 3.42063493, 3.52552538, 3.55433226, 3.49523143,
#        3.51812521, 3.57148033, 3.49305636, 3.49808923, 3.54273314,
#        3.58158689, 3.54273314, 3.65834383, 3.63668404, 3.38223107,
#        3.54163843, 3.62063647, 3.44829819, 3.47620275, 3.69155946,
#        3.50503183, 3.42824311, 3.65281232, 3.62023614, 3.42284307,
#        3.57037087, 3.47700581, 3.48636053, 3.50435011, 3.59292123,
#        3.64223346, 3.60581752, 3.57267414, 3.51300751, 3.53377209,
#        3.43755724, 3.53718791, 3.48483639, 3.52431407, 3.61907676,
#        3.50972938, 3.51397882, 3.48787125, 3.42284307, 3.54042608,
#        3.47700581, 3.564232  , 3.57539744, 3.60193526, 3.56436082,
#        3.55320727, 3.57037087, 3.56873979, 3.54273314, 3.57462122,
#        3.564232  , 3.62927395, 3.46018513, 3.71970408, 3.60581752,
#        3.59534025, 3.47700581, 3.55935415, 3.75730747, 3.54273314,
#        3.5557534 , 3.47377078, 3.50826686, 3.4713039 , 3.69223653,
#        3.68877845, 3.67814687, 3.38223107, 3.62023614, 3.61674515,
#        3.49950045, 3.60731598, 3.52552538, 3.564232  , 3.4650219 ,
#        3.60731598, 3.54704296, 3.5977252 , 3.57718901, 3.47377078,
#        3.53133965, 3.66046796, 3.56034098, 3.51938105, 3.57539744,
#        3.51686008, 3.48936878, 3.66558726, 3.7397041 , 3.51397882,
#        3.42824311, 3.46368347])

# %%
y_test ## y test
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
x_train_pred_DT=DT.predict(x_train)  ## predicted x train

x_train_pred_DT
# Out:
# array([3.65995718, 3.47620275, 3.54651016, ..., 3.48018103, 3.60880129,
#        3.5989052 ])

# %%
y_train ## y train
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %%
print('Training score for Decision Tree Regressor is',DT.score(x_train,y_train))
# Out:
# Training score for Decision Tree Regressor is 1.0

# %%
print('Testing score for Decision Tree Regressor is',DT.score(x_test,y_test))
# Out:
# Testing score for Decision Tree Regressor is 0.9988519546041106

# %% [markdown]
# ### Training score is more than the Testing score,so the decision tree model is underfitting,So we can do hyper parametric tuning.

# %% [markdown]
# **Hyper parametric Tuning-- Decision Tree**

# %%
from sklearn.model_selection import RandomizedSearchCV

parameters={"splitter":["best","random"],
            "max_depth" : [2,4,6,8],
           "min_samples_leaf":[1,2,3,4,5,],
           "max_features":["auto","sqrt"],
           "max_leaf_nodes":[5,10,15] }

# %%
hyper_tuning_DT = RandomizedSearchCV(estimator=DT, param_distributions = parameters,
                               cv = 2, n_iter = 10, n_jobs=-1)

# %%
hyper_tuning_DT.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=2, estimator=DecisionTreeRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [2, 4, 6, 8],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'max_leaf_nodes': [5, 10, 15],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         'splitter': ['best', 'random']})

# %%
hyper_tuning_DT.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_leaf': 4,
#  'max_leaf_nodes': 15,
#  'max_features': 'auto',
#  'max_depth': 8}

# %%
hypertuning_DT = DecisionTreeRegressor(splitter= 'best',min_samples_leaf=5,max_leaf_nodes=15,max_features='sqrt',max_depth=6)

hypertuning_DT
# Out:
# DecisionTreeRegressor(max_depth=6, max_features='sqrt', max_leaf_nodes=15,
#                       min_samples_leaf=5)

# %%
hypertuning_DT.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, max_features='sqrt', max_leaf_nodes=15,
#                       min_samples_leaf=5)

# %%
DT_hyper_pred_xtest=hypertuning_DT.predict(x_test)

DT_hyper_pred_xtest
# Out:
# array([3.57343523, 3.53988054, 3.5154987 , 3.57343523, 3.47918439,
#        3.47918439, 3.58111988, 3.47918439, 3.64908482, 3.51569264,
#        3.58469859, 3.51569264, 3.58469859, 3.5154987 , 3.47918439,
#        3.5154987 , 3.58469859, 3.41433989, 3.5154987 , 3.61762807,
#        3.58111988, 3.5154987 , 3.5154987 , 3.58469859, 3.57343523,
#        3.53988054, 3.58111988, 3.41433989, 3.64509258, 3.5154987 ,
#        3.45373093, 3.58469859, 3.5154987 , 3.64908482, 3.64509258,
#        3.58469859, 3.64509258, 3.5154987 , 3.64908482, 3.64509258,
#        3.57343523, 3.47918439, 3.58469859, 3.64509258, 3.64908482,
#        3.51569264, 3.47918439, 3.5154987 , 3.57343523, 3.47918439,
#        3.64509258, 3.5154987 , 3.57343523, 3.43979883, 3.58469859,
#        3.5154987 , 3.51569264, 3.64509258, 3.5154987 , 3.47918439,
#        3.5154987 , 3.5154987 , 3.5154987 , 3.5154987 , 3.58469859,
#        3.53988054, 3.5154987 , 3.58111988, 3.57343523, 3.58469859,
#        3.58469859, 3.47918439, 3.45043754, 3.64509258, 3.5154987 ,
#        3.64509258, 3.5154987 , 3.47918439, 3.64908482, 3.58111988,
#        3.47918439, 3.5154987 , 3.43979883, 3.47918439, 3.57343523,
#        3.58111988, 3.47918439, 3.58469859, 3.58111988, 3.5154987 ,
#        3.58111988, 3.57343523, 3.58469859, 3.58111988, 3.58469859,
#        3.5154987 , 3.58111988, 3.57343523, 3.5154987 , 3.57343523,
#        3.58111988, 3.64908482, 3.47918439, 3.53988054, 3.47918439,
#        3.64908482, 3.5154987 , 3.47918439, 3.58469859, 3.41433989,
#        3.47918439, 3.5154987 , 3.57343523, 3.5154987 , 3.58111988,
#        3.57343523, 3.64509258, 3.5154987 , 3.57343523, 3.64509258,
#        3.43979883, 3.51569264, 3.5154987 , 3.57343523, 3.58111988,
#        3.58469859, 3.64509258, 3.58469859, 3.47918439, 3.57343523,
#        3.58111988, 3.58111988, 3.51569264, 3.57343523, 3.5154987 ,
#        3.58469859, 3.57343523, 3.58111988, 3.47918439, 3.58111988,
#        3.5154987 , 3.47918439, 3.57343523, 3.51569264, 3.47918439,
#        3.58469859, 3.58111988, 3.5154987 , 3.64509258, 3.58469859,
#        3.57343523, 3.61762807, 3.58111988, 3.51569264, 3.53988054,
#        3.57343523, 3.47918439, 3.53988054, 3.43979883, 3.58469859,
#        3.5154987 , 3.5154987 , 3.58111988, 3.47918439, 3.64509258,
#        3.51569264, 3.58469859, 3.58469859, 3.58469859, 3.58469859,
#        3.53988054, 3.57343523, 3.58469859, 3.58469859, 3.5154987 ,
#        3.45043754, 3.5154987 , 3.57343523, 3.45373093, 3.5154987 ,
#        3.53988054, 3.57343523, 3.47918439, 3.64509258, 3.5154987 ,
#        3.53988054, 3.47918439, 3.58111988, 3.53988054, 3.47918439,
#        3.47918439, 3.5154987 , 3.58111988, 3.47918439, 3.45043754,
#        3.47918439, 3.47918439, 3.5154987 , 3.53988054, 3.47918439,
#        3.5154987 , 3.64509258, 3.5154987 , 3.51569264, 3.58111988,
#        3.58111988, 3.5154987 , 3.64509258, 3.64509258, 3.41433989,
#        3.5154987 , 3.58111988, 3.45373093, 3.41433989, 3.53988054,
#        3.57343523, 3.57343523, 3.64908482, 3.58111988, 3.41433989,
#        3.57343523, 3.53988054, 3.53988054, 3.5154987 , 3.58469859,
#        3.58469859, 3.64509258, 3.57343523, 3.5154987 , 3.57343523,
#        3.45373093, 3.47918439, 3.43979883, 3.5154987 , 3.58469859,
#        3.53988054, 3.51569264, 3.5154987 , 3.45373093, 3.57343523,
#        3.47918439, 3.58469859, 3.58469859, 3.58469859, 3.57343523,
#        3.5154987 , 3.5154987 , 3.58111988, 3.5154987 , 3.58111988,
#        3.53988054, 3.64509258, 3.41433989, 3.64509258, 3.58111988,
#        3.58469859, 3.41433989, 3.58469859, 3.64908482, 3.64509258,
#        3.58111988, 3.53988054, 3.51569264, 3.45373093, 3.64509258,
#        3.64509258, 3.57343523, 3.47918439, 3.53988054, 3.58111988,
#        3.53988054, 3.53988054, 3.53988054, 3.57343523, 3.53988054,
#        3.58111988, 3.58111988, 3.53988054, 3.64908482, 3.47918439,
#        3.5154987 , 3.64509258, 3.53988054, 3.53988054, 3.58469859,
#        3.51569264, 3.47918439, 3.53988054, 3.64509258, 3.57343523,
#        3.41433989, 3.47918439])

# %%
y_test
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
DT_hyper_pred_xtrain=hypertuning_DT.predict(x_train)

DT_hyper_pred_xtrain
# Out:
# array([3.64509258, 3.47918439, 3.5154987 , ..., 3.45373093, 3.58469859,
#        3.58111988])

# %%
y_train
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %%
print('Training score for hyper parametric tuning of Decision tree regressor is',hypertuning_DT.score(x_train,y_train))
# Out:
# Training score for hyper parametric tuning of Decision tree regressor is 0.7127545395699806

# %%
print('Testing score for hyper parametric tuning of Decision tree regressor is',hypertuning_DT.score(x_test,y_test))
# Out:
# Testing score for hyper parametric tuning of Decision tree regressor is 0.647377210586486

# %% [markdown]
# ## Xtreme Gradient Boosting

# %%
from xgboost import XGBRegressor
XGB=XGBRegressor()
XGB.fit(x_train,y_train) 

xtest_XGB_pred=XGB.predict(x_test) ## predicted x test

# %%
xtest_XGB_pred
# Out:
# array([3.5804195, 3.5103054, 3.4764278, 3.5748086, 3.4349697, 3.4344463,
#        3.643563 , 3.5222733, 3.8059235, 3.5314527, 3.5899923, 3.515817 ,
#        3.6016371, 3.49926  , 3.491044 , 3.5255287, 3.5726929, 3.4991171,
#        3.5315993, 3.5365124, 3.5473175, 3.5243623, 3.4761117, 3.5577767,
#        3.568932 , 3.551433 , 3.5605288, 3.4326615, 3.658815 , 3.4897733,
#        3.4766014, 3.591814 , 3.5388033, 3.6194303, 3.6911347, 3.5589206,
#        3.6374202, 3.4811525, 3.6310985, 3.668719 , 3.615722 , 3.5071023,
#        3.547313 , 3.6381884, 3.7007473, 3.4914076, 3.4996274, 3.5029616,
#        3.5561726, 3.4345105, 3.7138174, 3.539015 , 3.5519536, 3.4583936,
#        3.635957 , 3.4984612, 3.509807 , 3.6133192, 3.5179055, 3.4842527,
#        3.5162833, 3.5121827, 3.5120094, 3.5627384, 3.575459 , 3.5390275,
#        3.5093818, 3.6014178, 3.5179567, 3.601737 , 3.5711436, 3.4908044,
#        3.4254634, 3.7006123, 3.4809659, 3.6184475, 3.5118768, 3.4192393,
#        3.658722 , 3.5413747, 3.5187583, 3.5153887, 3.4737575, 3.525392 ,
#        3.580147 , 3.5689344, 3.4674492, 3.584907 , 3.569075 , 3.5152574,
#        3.580663 , 3.5724843, 3.5704672, 3.5806177, 3.5560067, 3.5387404,
#        3.5915914, 3.568124 , 3.499072 , 3.5454433, 3.6273654, 3.581936 ,
#        3.4920545, 3.5418465, 3.4705794, 3.627245 , 3.5235474, 3.4707537,
#        3.5630283, 3.502452 , 3.4380844, 3.4896064, 3.572673 , 3.4921923,
#        3.5664792, 3.536183 , 3.693582 , 3.5102835, 3.5753922, 3.634959 ,
#        3.521974 , 3.5266805, 3.504948 , 3.5592124, 3.5941536, 3.601072 ,
#        3.7160509, 3.5709665, 3.5803459, 3.5633414, 3.5872633, 3.575551 ,
#        3.523715 , 3.5663626, 3.4851959, 3.5918458, 3.5184603, 3.5628765,
#        3.4735782, 3.559192 , 3.5412524, 3.5255296, 3.5956237, 3.5332205,
#        3.473253 , 3.5473769, 3.5806086, 3.5261173, 3.6597946, 3.593967 ,
#        3.563212 , 3.69171  , 3.6125534, 3.5269964, 3.5441546, 3.6200974,
#        3.4396114, 3.6070495, 3.5277495, 3.5467165, 3.4544554, 3.5225008,
#        3.5786095, 3.5046809, 3.607601 , 3.4840162, 3.55866  , 3.630858 ,
#        3.5879235, 3.5647502, 3.5594645, 3.5539935, 3.5777464, 3.5591571,
#        3.479509 , 3.518231 , 3.5117917, 3.6128259, 3.4810297, 3.5112782,
#        3.6593783, 3.55413  , 3.4852467, 3.655505 , 3.4242916, 3.5598526,
#        3.4710917, 3.5754883, 3.5754364, 3.5384135, 3.51696  , 3.560347 ,
#        3.5942638, 3.527822 , 3.5026805, 3.522861 , 3.4142292, 3.5253623,
#        3.5539832, 3.4941607, 3.5178561, 3.571234 , 3.492503 , 3.4991686,
#        3.5423772, 3.581958 , 3.5420501, 3.658355 , 3.6364079, 3.3886101,
#        3.541293 , 3.6197445, 3.448696 , 3.4757469, 3.688561 , 3.5050821,
#        3.426125 , 3.6521063, 3.6193795, 3.4190342, 3.5707612, 3.476498 ,
#        3.4881763, 3.5049398, 3.5914528, 3.6434488, 3.6069832, 3.5730648,
#        3.5121827, 3.5343082, 3.43897  , 3.5363169, 3.4843442, 3.5245595,
#        3.6181283, 3.5100524, 3.5154092, 3.487923 , 3.4228644, 3.5409641,
#        3.476589 , 3.5646846, 3.5750382, 3.6007679, 3.5644994, 3.55352  ,
#        3.570517 , 3.5687783, 3.54238  , 3.5750892, 3.5665903, 3.6317613,
#        3.458817 , 3.7143033, 3.6031985, 3.595088 , 3.4767466, 3.559463 ,
#        3.7575817, 3.542195 , 3.5560927, 3.47424  , 3.509104 , 3.4712346,
#        3.6868088, 3.6906593, 3.6768086, 3.3903909, 3.6193397, 3.6167872,
#        3.499829 , 3.6090796, 3.5254736, 3.564325 , 3.4690983, 3.6087685,
#        3.5472298, 3.5967846, 3.5765817, 3.4738598, 3.5310915, 3.6589677,
#        3.5604537, 3.5190327, 3.5753598, 3.517228 , 3.4903703, 3.6674793,
#        3.7583406, 3.5152278, 3.4194086, 3.4598181], dtype=float32)

# %%
xtrain_XGB_pred=XGB.predict(x_train)

# %%
xtrain_XGB_pred
# Out:
# array([3.6601756, 3.4765882, 3.5458307, ..., 3.4809775, 3.6091924,
#        3.5997462], dtype=float32)

# %%
print('Training score for XGB is',XGB.score(x_train,y_train))
# Out:
# Training score for XGB is 0.9999337232252173

# %%
print('Testing score for XGB is',XGB.score(x_test,y_test))
# Out:
# Testing score for XGB is 0.9994552530996582

# %%
x_XGB_pred=XGB.predict(x)

# %% [markdown]
# # **OUTPUT**

# %%
data=pd.read_csv('train.csv')

# %%
my_submission = pd.DataFrame({'Id': data.Id, 'SalePrice': x_XGB_pred})

# %%
my_submission
# Out:
#         Id  SalePrice
# 0        1       3.80
# 1        2       3.78
# 2        3       3.80
# 3        4       3.81
# 4        5       3.81
# ...    ...        ...
# 1455  1456       3.80
# 1456  1457       3.78
# 1457  1458       3.80
# 1458  1459       3.77
# 1459  1460       3.78
#
# [1460 rows x 2 columns]

# %%
# save the prediction
my_submission.to_csv('submission.csv', index=False)
